# %% [markdown]
# 1-Pandas is a Python library (Python Data Analysis library).
#
# 2-Pandas is used to analyze differents types of data like csv - json - excel.
#
# 3-It has functions for analyzing, cleaning, exploring, and manipulating data.

# %% [markdown]
# # Part 1 !

# %%
import pandas as pd

# %%
df=pd.read_csv('car.csv')
df
# Out:
#         name  year  km_driven    fuel seller_type transmission  \
# 0        BMW  2014     145500  Diesel  Individual       Manual
# 1      Honda  2014     120000  Diesel  Individual       Manual
# 2     Toyota  2006     140000  Petrol  Individual       Manual
# 3       Ford  2010     127000  Diesel  Individual       Manual
# 4      Honda  2007     120000  Petrol  Individual       Manual
# ...      ...   ...        ...     ...         ...          ...
# 8123    Ford  2013     110000  Petrol  Individual       Manual
# 8124  Nissan  2007     119000  Diesel  Individual       Manual
# 8125     BMW  2009     120000  Diesel  Individual       Manual
# 8126    Ford  2013      25000  Diesel  Individual       Manual
# 8127  Toyota  2013      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats  selling_price
# 0              First Owner    23.40  1248.0      74.00    5.0         450000
# ...

# %%
df.info() # -> display the info of data  , object --> refer to string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   km_driven      8128 non-null   int64
#  3   fuel           8128 non-null   object
#  4   seller_type    8128 non-null   object
#  5   transmission   8128 non-null   object
#  6   owner          8128 non-null   object
#  7   mileage        7907 non-null   float64
#  8   engine         7907 non-null   float64
#  9   max_power      7912 non-null   float64
#  10  seats          7907 non-null   float64
#  11  selling_price  8128 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 762.1+ KB

# %%
df.describe() # describe min , max ,mean .std for each column
# Out:
#               year     km_driven      mileage       engine    max_power  \
# count  8128.000000  8.128000e+03  7907.000000  7907.000000  7912.000000
# mean   2013.804011  6.981951e+04    19.418783  1458.625016    91.517919
# std       4.044249  5.655055e+04     4.037145   503.916303    35.822499
# min    1983.000000  1.000000e+00     0.000000   624.000000     0.000000
# 25%    2011.000000  3.500000e+04    16.780000  1197.000000    68.050000
# 50%    2015.000000  6.000000e+04    19.300000  1248.000000    82.000000
# 75%    2017.000000  9.800000e+04    22.320000  1582.000000   102.000000
# max    2020.000000  2.360457e+06    42.000000  3604.000000   400.000000
#
#              seats  selling_price
# count  7907.000000   8.128000e+03
# mean      5.416719   6.382718e+05
# std       0.959588   8.062534e+05
# min       2.000000   2.999900e+04
# 25%       5.000000   2.549990e+05
# 50%       5.000000   4.500000e+05
# 75%       5.000000   6.750000e+05
# max      14.000000   1.000000e+07

# %%
df.head(10) # --> print the first (n) 10 rows
# Out:
#      name  year  km_driven    fuel seller_type transmission         owner  \
# 0     BMW  2014     145500  Diesel  Individual       Manual   First Owner
# 1   Honda  2014     120000  Diesel  Individual       Manual  Second Owner
# 2  Toyota  2006     140000  Petrol  Individual       Manual   Third Owner
# 3    Ford  2010     127000  Diesel  Individual       Manual   First Owner
# 4   Honda  2007     120000  Petrol  Individual       Manual   First Owner
# 5     BMW  2017      45000  Petrol  Individual       Manual   First Owner
# 6  Nissan  2007     175000     LPG  Individual       Manual   First Owner
# 7    Ford  2001       5000  Petrol  Individual       Manual  Second Owner
# 8    Ford  2011      90000  Diesel  Individual       Manual   First Owner
# 9   Honda  2013     169000  Diesel  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats  selling_price
# 0    23.40  1248.0      74.00    5.0         450000
# ...

# %%
df.tail(10) # --> print the tail (n) 10 rows من تحت !
# Out:
#         name  year  km_driven    fuel seller_type transmission  \
# 8118    Ford  2013      25000  Petrol  Individual       Manual
# 8119  Nissan  2017      80000  Petrol  Individual       Manual
# 8120   Honda  2008     191000  Petrol  Individual       Manual
# 8121  Nissan  2013      50000  Petrol  Individual       Manual
# 8122     BMW  2014      80000  Diesel  Individual       Manual
# 8123    Ford  2013     110000  Petrol  Individual       Manual
# 8124  Nissan  2007     119000  Diesel  Individual       Manual
# 8125     BMW  2009     120000  Diesel  Individual       Manual
# 8126    Ford  2013      25000  Diesel  Individual       Manual
# 8127  Toyota  2013      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats  selling_price
# 8118           First Owner    18.50  1197.0      82.85    5.0         380000
# 8119           First Owner    20.51   998.0      67.04    5.0         360000
# ...

# %%
df.columns
# Out:
# Index(['name', 'year', 'km_driven', 'fuel', 'seller_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'seats', 'selling_price'],
#       dtype='object')

# %%
df.name
# Out:
# 0          BMW
# 1        Honda
# 2       Toyota
# 3         Ford
# 4        Honda
#          ...
# 8123      Ford
# 8124    Nissan
# 8125       BMW
# 8126      Ford
# 8127    Toyota
# Name: name, Length: 8128, dtype: object

# %%
df['name']
# Out:
# 0          BMW
# 1        Honda
# 2       Toyota
# 3         Ford
# 4        Honda
#          ...
# 8123      Ford
# 8124    Nissan
# 8125       BMW
# 8126      Ford
# 8127    Toyota
# Name: name, Length: 8128, dtype: object

# %%
df['transmission'].value_counts() # divide the values of col
# Out:
# transmission
# Manual       7078
# Automatic    1050
# Name: count, dtype: int64

# %%
df.iloc[:,:-1]  # access using iloc function
# -->  in NumPy like a[:,:-1] because it is an array (direct access)
# Out:
#         name  year  km_driven    fuel seller_type transmission  \
# 0        BMW  2014     145500  Diesel  Individual       Manual
# 1      Honda  2014     120000  Diesel  Individual       Manual
# 2     Toyota  2006     140000  Petrol  Individual       Manual
# 3       Ford  2010     127000  Diesel  Individual       Manual
# 4      Honda  2007     120000  Petrol  Individual       Manual
# ...      ...   ...        ...     ...         ...          ...
# 8123    Ford  2013     110000  Petrol  Individual       Manual
# 8124  Nissan  2007     119000  Diesel  Individual       Manual
# 8125     BMW  2009     120000  Diesel  Individual       Manual
# 8126    Ford  2013      25000  Diesel  Individual       Manual
# 8127  Toyota  2013      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats
# 0              First Owner    23.40  1248.0      74.00    5.0
# 1             Second Owner    21.14  1498.0     103.52    5.0
# ...

# %%
df.set_index('name')
# Out:
#         year  km_driven    fuel seller_type transmission  \
# name
# BMW     2014     145500  Diesel  Individual       Manual
# Honda   2014     120000  Diesel  Individual       Manual
# Toyota  2006     140000  Petrol  Individual       Manual
# Ford    2010     127000  Diesel  Individual       Manual
# Honda   2007     120000  Petrol  Individual       Manual
# ...      ...        ...     ...         ...          ...
# Ford    2013     110000  Petrol  Individual       Manual
# Nissan  2007     119000  Diesel  Individual       Manual
# BMW     2009     120000  Diesel  Individual       Manual
# Ford    2013      25000  Diesel  Individual       Manual
# Toyota  2013      25000  Diesel  Individual       Manual
#
#                        owner  mileage  engine  max_power  seats  selling_price
# name
# BMW              First Owner    23.40  1248.0      74.00    5.0         450000
# Honda           Second Owner    21.14  1498.0     103.52    5.0         370000
# ...

# %%
df.set_index('name',inplace=True) # to access using it

# %%
df.loc['Ford'] # display all names called
# Out:
#       year  km_driven    fuel seller_type transmission         owner  mileage  \
# name
# Ford  2010     127000  Diesel  Individual       Manual   First Owner    23.00
# Ford  2001       5000  Petrol  Individual       Manual  Second Owner    16.10
# Ford  2011      90000  Diesel  Individual       Manual   First Owner    23.59
# Ford  2018      35000  Petrol  Individual       Manual   First Owner    20.30
# Ford  2009     120000  Petrol  Individual       Manual   First Owner    18.90
# ...    ...        ...     ...         ...          ...           ...      ...
# Ford  2004     120000  Petrol  Individual       Manual  Second Owner    13.00
# Ford  2010     129000  Diesel  Individual       Manual   First Owner    12.80
# Ford  2013      25000  Petrol  Individual       Manual   First Owner    18.50
# Ford  2013     110000  Petrol  Individual       Manual   First Owner    18.50
# Ford  2013      25000  Diesel  Individual       Manual   First Owner    23.57
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#         name  year  km_driven    fuel seller_type transmission  \
# 0        BMW  2014     145500  Diesel  Individual       Manual
# 1      Honda  2014     120000  Diesel  Individual       Manual
# 2     Toyota  2006     140000  Petrol  Individual       Manual
# 3       Ford  2010     127000  Diesel  Individual       Manual
# 4      Honda  2007     120000  Petrol  Individual       Manual
# ...      ...   ...        ...     ...         ...          ...
# 8123    Ford  2013     110000  Petrol  Individual       Manual
# 8124  Nissan  2007     119000  Diesel  Individual       Manual
# 8125     BMW  2009     120000  Diesel  Individual       Manual
# 8126    Ford  2013      25000  Diesel  Individual       Manual
# 8127  Toyota  2013      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats  selling_price
# 0              First Owner    23.40  1248.0      74.00    5.0         450000
# ...

# %% [markdown]
# # advanced example on index you can Skip it

# %%
data = {
  "age": [50, 40, 30, 40, 20, 10, 30],
  "qualified": [True, False, False, False, False, True, True]
}

index = ["Mary", "Sally", "Emil", "Tobias", "Linus", "John", "Peter"]

dataFrame = pd.DataFrame(data, index = index)
# the index become String from the list
newdf = dataFrame.sort_index() # sort the index 

print(newdf)
newdf.loc['Mary']
# Out:
#         age  qualified
# Emil     30      False
# John     10       True
# Linus    20      False
# Mary     50       True
# Peter    30       True
# Sally    40      False
# Tobias   40      False
# age            50
# qualified    True
# Name: Mary, dtype: object

# %% [markdown]
# # Filtering based on condition

# %%
df['name']=='Ford' # condition
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8123     True
# 8124    False
# 8125    False
# 8126     True
# 8127    False
# Name: name, Length: 8128, dtype: bool

# %%
condition=df['name']=='Ford' # condition
df[condition]
# Out:
#       name  year  km_driven    fuel seller_type transmission         owner  \
# 3     Ford  2010     127000  Diesel  Individual       Manual   First Owner
# 7     Ford  2001       5000  Petrol  Individual       Manual  Second Owner
# 8     Ford  2011      90000  Diesel  Individual       Manual   First Owner
# 24    Ford  2018      35000  Petrol  Individual       Manual   First Owner
# 28    Ford  2009     120000  Petrol  Individual       Manual   First Owner
# ...    ...   ...        ...     ...         ...          ...           ...
# 8105  Ford  2004     120000  Petrol  Individual       Manual  Second Owner
# 8113  Ford  2010     129000  Diesel  Individual       Manual   First Owner
# 8118  Ford  2013      25000  Petrol  Individual       Manual   First Owner
# 8123  Ford  2013     110000  Petrol  Individual       Manual   First Owner
# 8126  Ford  2013      25000  Diesel  Individual       Manual   First Owner
#
#       mileage  engine  max_power  seats  selling_price
# ...

# %%
df.loc[condition] # loc index
# Out:
#       name  year  km_driven    fuel seller_type transmission         owner  \
# 3     Ford  2010     127000  Diesel  Individual       Manual   First Owner
# 7     Ford  2001       5000  Petrol  Individual       Manual  Second Owner
# 8     Ford  2011      90000  Diesel  Individual       Manual   First Owner
# 24    Ford  2018      35000  Petrol  Individual       Manual   First Owner
# 28    Ford  2009     120000  Petrol  Individual       Manual   First Owner
# ...    ...   ...        ...     ...         ...          ...           ...
# 8105  Ford  2004     120000  Petrol  Individual       Manual  Second Owner
# 8113  Ford  2010     129000  Diesel  Individual       Manual   First Owner
# 8118  Ford  2013      25000  Petrol  Individual       Manual   First Owner
# 8123  Ford  2013     110000  Petrol  Individual       Manual   First Owner
# 8126  Ford  2013      25000  Diesel  Individual       Manual   First Owner
#
#       mileage  engine  max_power  seats  selling_price
# ...

# %% [markdown]
# # Differance between iloc and loc

# %%
df.iloc[0] # index integer only 
# or range of indexes like this
# df.iloc[0:2,0:2]
# Out:
# name                     BMW
# year                    2014
# km_driven             145500
# fuel                  Diesel
# seller_type       Individual
# transmission          Manual
# owner            First Owner
# mileage                 23.4
# engine                1248.0
# max_power               74.0
# seats                    5.0
# selling_price         450000
# Name: 0, dtype: object

# %%
df.loc[condition] # take condition or index or any thing
df.loc[condition,['name','fuel']] # or group of cols as String
# Out:
#       name    fuel
# 3     Ford  Diesel
# 7     Ford  Petrol
# 8     Ford  Diesel
# 24    Ford  Petrol
# 28    Ford  Petrol
# ...    ...     ...
# 8105  Ford  Petrol
# 8113  Ford  Diesel
# 8118  Ford  Petrol
# 8123  Ford  Petrol
# 8126  Ford  Diesel
#
# [1666 rows x 2 columns]

# %%
cars=['Ford','Honda','BMW']
carsCondition=df.isin(cars) # condition
df[carsCondition]
# Out:
#        name  year  km_driven fuel seller_type transmission owner  mileage  \
# 0       BMW   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 1     Honda   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 2       NaN   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 3      Ford   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 4     Honda   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# ...     ...   ...        ...  ...         ...          ...   ...      ...
# 8123   Ford   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 8124    NaN   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 8125    BMW   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 8126   Ford   NaN        NaN  NaN         NaN          NaN   NaN      NaN
# 8127    NaN   NaN        NaN  NaN         NaN          NaN   NaN      NaN
#
#       engine  max_power  seats  selling_price
# ...

# %%
filt=df['owner'].str.contains('Second')
#filt2=df['owner']=='Second Owner'
df[filt]
# Out:
#         name  year  km_driven    fuel seller_type transmission         owner  \
# 1      Honda  2014     120000  Diesel  Individual       Manual  Second Owner
# 7       Ford  2001       5000  Petrol  Individual       Manual  Second Owner
# 10    Toyota  2014      68000  Diesel  Individual       Manual  Second Owner
# 11    Toyota  2005     100000  Petrol  Individual       Manual  Second Owner
# 12     Honda  2009     140000  Diesel  Individual       Manual  Second Owner
# ...      ...   ...        ...     ...         ...          ...           ...
# 8104    Ford  2006      70000  Petrol  Individual       Manual  Second Owner
# 8105    Ford  2004     120000  Petrol  Individual       Manual  Second Owner
# 8106  Nissan  2012     128000  Diesel  Individual       Manual  Second Owner
# 8121  Nissan  2013      50000  Petrol  Individual       Manual  Second Owner
# 8122     BMW  2014      80000  Diesel  Individual       Manual  Second Owner
#
# ...

# %% [markdown]
# # Grouping and aggregation

# %%
df.median(numeric_only=True)
# Out:
# year               2015.0
# km_driven         60000.0
# mileage              19.3
# engine             1248.0
# max_power            82.0
# seats                 5.0
# selling_price    450000.0
# dtype: float64

# %%
df['engine'].median() # --> num only
df['engine'].mean() # --> num only
df['engine'].std() # --> num only
df.describe()
# Out:
#               year     km_driven      mileage       engine    max_power  \
# count  8128.000000  8.128000e+03  7907.000000  7907.000000  7912.000000
# mean   2013.804011  6.981951e+04    19.418783  1458.625016    91.517919
# std       4.044249  5.655055e+04     4.037145   503.916303    35.822499
# min    1983.000000  1.000000e+00     0.000000   624.000000     0.000000
# 25%    2011.000000  3.500000e+04    16.780000  1197.000000    68.050000
# 50%    2015.000000  6.000000e+04    19.300000  1248.000000    82.000000
# 75%    2017.000000  9.800000e+04    22.320000  1582.000000   102.000000
# max    2020.000000  2.360457e+06    42.000000  3604.000000   400.000000
#
#              seats  selling_price
# count  7907.000000   8.128000e+03
# mean      5.416719   6.382718e+05
# std       0.959588   8.062534e+05
# min       2.000000   2.999900e+04
# 25%       5.000000   2.549990e+05
# 50%       5.000000   4.500000e+05
# 75%       5.000000   6.750000e+05
# max      14.000000   1.000000e+07

# %%
df.max()
# Out:
# name                       Toyota
# year                         2020
# km_driven                 2360457
# fuel                       Petrol
# seller_type      Trustmark Dealer
# transmission               Manual
# owner                 Third Owner
# mileage                      42.0
# engine                     3604.0
# max_power                   400.0
# seats                        14.0
# selling_price            10000000
# dtype: object

# %%
df.min()
# Out:
# name                     BMW
# year                    1983
# km_driven                  1
# fuel                     CNG
# seller_type           Dealer
# transmission       Automatic
# owner            First Owner
# mileage                  0.0
# engine                 624.0
# max_power                0.0
# seats                    2.0
# selling_price          29999
# dtype: object

# %%
# filt=(df['name']=='BMW') | (df['name']=='Ford')
names=['BMW','Ford','Honda']
filt=df['name'].isin(names)
df.loc[filt,'name'].count()
# Out:
# 4822

# %% [markdown]
# # So So Important

# %%
df['transmission'].value_counts(normalize=True).mul(100).astype('i').astype('str') + ' %'
# Out:
# transmission
# Manual       87 %
# Automatic    12 %
# Name: proportion, dtype: object

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       7078
# Automatic    1050
# Name: count, dtype: int64

# %%
df['km_driven'].add(10)
df['km_driven'].sub(10)
df['km_driven'].div(10)
df['km_driven'].mul(10) # some functions
# Out:
# 0       1455000
# 1       1200000
# 2       1400000
# 3       1270000
# 4       1200000
#          ...
# 8123    1100000
# 8124    1190000
# 8125    1200000
# 8126     250000
# 8127     250000
# Name: km_driven, Length: 8128, dtype: int64

# %% [markdown]
# # Grouping

# %%
# very important
trans_group=df.groupby(['transmission','fuel'])
result=trans_group.get_group(('Automatic','Petrol'))
result[['transmission','fuel']]
# Out:
#      transmission    fuel
# 41      Automatic  Petrol
# 44      Automatic  Petrol
# 58      Automatic  Petrol
# 69      Automatic  Petrol
# 82      Automatic  Petrol
# ...           ...     ...
# 8057    Automatic  Petrol
# 8058    Automatic  Petrol
# 8063    Automatic  Petrol
# 8081    Automatic  Petrol
# 8086    Automatic  Petrol
#
# [516 rows x 2 columns]

# %%
filt=(df['transmission'] == 'Automatic') & (df['fuel'] == 'Petrol')
df.loc[filt,['transmission','fuel']] # take care the condition in the fisrt
# Out:
#      transmission    fuel
# 41      Automatic  Petrol
# 44      Automatic  Petrol
# 58      Automatic  Petrol
# 69      Automatic  Petrol
# 82      Automatic  Petrol
# ...           ...     ...
# 8057    Automatic  Petrol
# 8058    Automatic  Petrol
# 8063    Automatic  Petrol
# 8081    Automatic  Petrol
# 8086    Automatic  Petrol
#
# [516 rows x 2 columns]

# %%
# result=trans_group.get_group(('Automatic','Petrol'))   --> group (Auto,Petrol)
result['name'].value_counts().loc['BMW']  # i need how many BMW are AUTO and PETROL
# Out:
# 91

# %%
df['km_driven'].agg(['min','max','mean','median'])
# Out:
# min       1.000000e+00
# max       2.360457e+06
# mean      6.981951e+04
# median    6.000000e+04
# Name: km_driven, dtype: float64

# %%
# cars  seates greater than 5 
filt=df['seats'] == 5
df.loc[filt,'seats'].count() # sum جمع & count تعد
# Out:
# 6254

# %%
condition=(df['name']=='BMW')
df.loc[condition,'name'].count()
# Out:
# 1548

# %%
names=df['name'].value_counts()
trans=df['transmission'].value_counts()
concat=pd.concat([trans,names],axis='columns')

# %%
concat.rename(columns={'count':'result'})
# Out:
#            result  result
# Manual     7078.0     NaN
# Automatic  1050.0     NaN
# Toyota        NaN  1686.0
# Ford          NaN  1666.0
# Nissan        NaN  1620.0
# Honda         NaN  1608.0
# BMW           NaN  1548.0

# %% [markdown]
# # Cleaning the missing values

# %%
import numpy as np


people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
peopledata=pd.DataFrame(people) # missing and NA is custom null
peopledata
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
# null should be np.nan null(not a number) or None
peopledata.dropna(axis='columns') # drop the columns which have null
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
peopledata.dropna(axis='index',how='all') # all the row ( index )  is null
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
peopledata.dropna(axis='index',how='any') # any value in the row ( index )  is null
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
peopledata.dropna(axis='index',how='any',subset=['last'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 6     NA  Missing                       NA  Missing

# %%
# Keep only the rows with at least 1 non-NA values.
peopledata.dropna(thresh=1)
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
peopledata.drop(columns=['first']) # drop specified column
# Out:
#       last                    email      age
# 0  Schafer  CoreyMSchafer@gmail.com       33
# 1      Doe        JaneDoe@email.com       55
# 2      Doe        JohnDoe@email.com       63
# 3  Schafer                     None       36
# 4      NaN                      NaN     None
# 5      NaN      Anonymous@email.com     None
# 6  Missing                       NA  Missing

# %% [markdown]
# # What about Custom null??

# %%
peopledata.replace('Missing',None,inplace=True)
peopledata.replace('NA',None,inplace=True)
peopledata
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6   None     None                     None  None

# %%
peopledata.isna().value_counts()
# Out:
# first  last   email  age
# False  False  False  False    3
# True   True   True   True     2
# False  False  True   False    1
# True   True   False  True     1
# Name: count, dtype: int64

# %%
peopledata.fillna('MISSING!')
# Out:
#       first      last                    email       age
# 0     Corey   Schafer  CoreyMSchafer@gmail.com        33
# 1      Jane       Doe        JaneDoe@email.com        55
# 2      John       Doe        JohnDoe@email.com        63
# 3     Chris   Schafer                 MISSING!        36
# 4  MISSING!  MISSING!                 MISSING!  MISSING!
# 5  MISSING!  MISSING!      Anonymous@email.com  MISSING!
# 6  MISSING!  MISSING!                 MISSING!  MISSING!

# %%
peopledata.columns
# Out:
# Index(['first', 'last', 'email', 'age'], dtype='object')

# %%
peopledata.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
peopledata['age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 peopledata['age'].astype(int)
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File c:\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
type(np.nan) # type of null is float
# Out:
# float

# %%
peopledata['age'].astype('float')
# Out:
# 0    33.0
# 1    55.0
# 2    63.0
# 3    36.0
# 4     NaN
# 5     NaN
# 6     NaN
# Name: age, dtype: float64

# %%
peopledata['age'].mean()
# Out:
# 46.75

# %%
peopledata['email'].unique()
# Out:
# array(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com',
#        'JohnDoe@email.com', None, nan, 'Anonymous@email.com'],
#       dtype=object)
